# %%
path_in = "C:/Users/ziane/py/stageM2/beja/trees/BEJ_MV_NARR_01_SHELTER (1).conllu"
path_out = "C:/Users/ziane/py/stageM2/beja/annot/calcul.conllu"

# %%
with open(path_in, "r", encoding="utf-8") as f:
    corpus = []
    for i in f:
        corpus.append(i)

# %%
with open(path_out, "w", encoding="utf-8") as t:

    for i, l in enumerate(corpus):
        if len(l)==1:
            continue
        
        if l.startswith('# sent_id =')==True and '001-' in l:
            t.write(l)
            continue
        
        elif l.startswith('# sent_id =')==True:
            t.write('\n')
            t.write(l)
            print(l)
            continue
        
        elif l.startswith('#')==True:
            print(l)
            t.write(l)
            continue
        
        """    
        if l.startswith('# user_id =')==True:
            t.write('\n')
            t.write(l)
            continue
            
        elif l.startswith('#')==True:
            print(l)
            t.write(l)
            continue
        """
                
        l = l.split('\t')
        try:
            lp = corpus[i-1].split('\t')
            lp2 = corpus[i-2].split('\t')
            ls = corpus[i+1].split('\t')
            ls2 = corpus[i+2].split('\t')
        except IndexError:
            pass
        
        #Linker
        try:
            if l[3]=='_' and ('-L' in l[9]) and l[1].endswith('-'):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+'X'+'\t'+l[4]+'\t'+l[5]+'\t'+l[6]+'\t'+l[7]+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #Linker
        try:
            if l[3]=='_' and ('-L' in l[9]) and l[1].startswith('-'):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+'X'+'\t'+l[4]+'\t'+l[5]+'\t'+l[6]+'\t'+l[7]+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #part > pronom (préposé)
        try:
            if l[3]=='PART' and ('PNG' in l[4]) and ls[3]=='VERB' and l[1].endswith('-'):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+'PRON'+'\t'+l[4]+'\t'+l[5]+'\t'+l[6]+'\t'+l[7]+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #part > pronom (préposé)   
        try:    
            if l[3]=='PART' and ('PNG' in l[4]) and ls2[3]=='VERB' and l[1].endswith('-'):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+'PRON'+'\t'+l[4]+'\t'+l[5]+'\t'+l[6]+'\t'+l[7]+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass

        #part > pronom (préposé)
        try:
            if l[3]=='PART' and ('OBJ' in l[9]) and ls[3]=='VERB' and l[1].endswith('-'):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+'PRON'+'\t'+l[4]+'\t'+l[5]+'\t'+l[6]+'\t'+l[7]+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #part > pronom (postposé) 
        if l[3]=='PART' and ('PNG' in l[9]) and lp[3]=='VERB' and l[1].startswith('-'):
            l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+'PRON'+'\t'+l[4]+'\t'+l[5]+'\t'+l[6]+'\t'+l[7]+'\t'+l[8]+'\t'+l[9])\
            .split('\t')
            
        #part > pronom (postposé)
        if l[3]=='PART' and ('PNG' in l[9]) and lp2[3]=='VERB' and l[1].startswith('-'):
            l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+'PRON'+'\t'+l[4]+'\t'+l[5]+'\t'+l[6]+'\t'+l[7]+'\t'+l[8]+'\t'+l[9])\
            .split('\t')

        #converb > SCONJ
        if l[4]=='CVB' and lp[3]=='VERB' and l[1].startswith('-'):
            l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+'SCONJ'+'\t'+l[4]+'\t'+l[5]+'\t'+l[6]+'\t'+l[7]+'\t'+l[8]+'\t'+l[9])\
            .split('\t')
            
        #csl > CCONJ
        if l[3]=='SCONJ' and ('CSL' in l[9]):
            l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+'CCONJ'+'\t'+l[4]+'\t'+l[5]+'\t'+l[6]+'\t'+l[7]+'\t'+l[8]+'\t'+l[9])\
            .split('\t')
            
        #VERB > AUX
        if l[3]=='VERB' and ('V' in l[9]) and ('DER' in l[9]) and (l[1].startswith('-') or l[1].endswith('-')):
            l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+'AUX'+'\t'+l[4]+'\t'+l[5]+'\t'+l[6]+'\t'+l[7]+'\t'+l[8]+'\t'+l[9])\
            .split('\t')
            
        #COP > AUX
        if l[3]=='NOUN' and ('COP' in l[9]) and ('VerbType=Cop' in l[5]):
            l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+'AUX'+'\t'+l[4]+'\t'+l[5]+'\t'+l[6]+'\t'+l[7]+'\t'+l[8]+'\t'+l[9])\
            .split('\t')
            
        #COP > AUX
        if l[3]=='PART' and ('OPT' in l[9]):
            l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+'AUX'+'\t'+l[4]+'\t'+l[5]+'\t'+l[6]+'\t'+l[7]+'\t'+l[8]+'\t'+l[9])\
            .split('\t')
            
        #part > aux (emphatique)
        if l[3]=='PART' and ('EMPH' in l[9]):
            l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+'AUX'+'\t'+l[4]+'\t'+l[5]+'\t'+l[6]+'\t'+l[7]+'\t'+l[8]+'\t'+l[9])\
            .split('\t')

        #DEM > DET
        if l[4]=='DEM' and ls[3]=='DET':
            l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+'DET'+'\t'+l[4]+'\t'+l[5]+'\t'+l[6]+'\t'+l[7]+'\t'+l[8]+'\t'+l[9])\
            .split('\t')
            
        # bug -, > cPART
        if ('-,' in l[9]) and lp[3]=='NOUN' and l[1].startswith('-'):
            l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+'PART'+'\t'+l[4]+'\t'+l[5]+'\t'+l[6]+'\t'+l[7]+'\t'+l[8]+'\t'+l[9])\
            .split('\t')
            
        print(l)
        t.write("\t".join(l))
# Out:
# # text = tak / kaːmi / hoː kʷiɖja ini //
#
# # tokenized_text = tak / kaːm =i / hoː kʷiɖ -ja i- ni //
#
# # text_en = A man said: "My camel disappeared.
#
# ['1', 'tak', '_', 'NOUN', 'N', 'Gender=Masc', '_', '_', '_', 'RX= SBJ,N,M|Gloss= man|Times= 0, 190\n']
# ['2', '/', '_', 'PUNCT', 'PUNCT', '_', '_', '_', '_', 'GE= PUNCT|RX= PUNCT|Times= 190, 879\n']
# ['3', 'kaːm', '_', 'NOUN', 'N', '_', '_', '_', '_', 'RX= SBJ,N|Gloss= camel|Times= 879, 982\n']
# ['4', '=i', '_', 'PRON', 'PRO', 'Poss=Yes|Person=1|Number=Sing|Case=Nom', '_', '_', '_', 'GE= =POSS,1SG,NOM|RX= =PRO|Times= 982, 1085\n']
# ['5', '/', '_', 'PUNCT', 'PUNCT', '_', '_', '_', '_', 'GE= PUNCT|RX= PUNCT|Times= 1085, 1815\n']
# ['6', 'hoː', '_', 'PRON', 'PRO', 'Person=1|Number=Sing|Case=Dat', '_', '_', '_', 'GE= 1SG,DAT|RX= PRO|Times= 1815, 2092\n']
# ['7', 'kʷiɖ', '_', 'VERB', 'V2', 'VerbClass=2', '_', '_', '_', 'RX= V2|Gloss= disappear|Times= 2092, 2231\n']
# ...

# %%
with open(path_out, "r", encoding="utf-8") as f:
    corpus = []
    for i in f:
        corpus.append(i)

# %%
for i in corpus:
    print(i)
# Out:
# # sent_id = BEJ_MV_NARR_01_shelter_001-005
#
# # text = tak / kaːmi / hoː kʷiɖja ini //
#
# # tokenized_text = tak / kaːm =i / hoː kʷiɖ -ja i- ni //
#
# # text_en = A man said: "My camel disappeared.
#
# 1	tak	_	NOUN	N	Gender=Masc	_	_	_	RX= SBJ,N,M|Gloss= man|Times= 0, 190
#
# 2	/	_	PUNCT	PUNCT	_	_	_	_	GE= PUNCT|RX= PUNCT|Times= 190, 879
#
# 3	kaːm	_	NOUN	N	_	_	_	_	RX= SBJ,N|Gloss= camel|Times= 879, 982
#
# 4	=i	_	PRON	PRO	Poss=Yes|Person=1|Number=Sing|Case=Nom	_	_	_	GE= =POSS,1SG,NOM|RX= =PRO|Times= 982, 1085
#
# 5	/	_	PUNCT	PUNCT	_	_	_	_	GE= PUNCT|RX= PUNCT|Times= 1085, 1815
#
# 6	hoː	_	PRON	PRO	Person=1|Number=Sing|Case=Dat	_	_	_	GE= 1SG,DAT|RX= PRO|Times= 1815, 2092
#
# 7	kʷiɖ	_	VERB	V2	VerbClass=2	_	_	_	RX= V2|Gloss= disappear|Times= 2092, 2231
#
# 8	-ja	_	PRON	TAM, PNG	Person=3|Number=Sing|Gender=Masc	_	_	_	GE= -PFV,3SG,M|RX= -TAM,PNG|Times= 2231, 2370
#
# 9	i-	_	PRON	PNG	Person=3|Number=Sing|Gender=Masc	_	_	_	GE= 3SG,M-|RX= PNG-|Times= 2370, 2509
#
# ...

# %%
with open(path_out, "w", encoding="utf-8") as out:

    for i, l in enumerate(corpus):
        if len(l)==1:
            continue
        """    
        if l.startswith('# user_id =')==True:
            out.write('\n')
            out.write(l)
            continue
            
        elif l.startswith('#')==True:
            print(l)
            out.write(l)
            continue
        """
        if l.startswith('# sent_id =')==True and '001-' in l:
            out.write(l)
            continue
        
        elif l.startswith('# sent_id =')==True:
            out.write('\n')
            out.write(l)
            print('XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX')
            print(l)
            continue
        
        elif l.startswith('#')==True:
            print(l)
            out.write(l)
            continue
        
        
        l = l.split('\t')
        try:
            lp = corpus[i-1].split('\t')
            lp2 = corpus[i-2].split('\t')
            lp3 = corpus[i-3].split('\t')
            ls = corpus[i+1].split('\t')
            ls2 = corpus[i+2].split('\t')
            ls3 = corpus[i+3].split('\t')
        except IndexError:
            pass
        
        ############################################################################################################
        #contexte 3
        ############################################################################################################
        
        #rel cc (ls=NOUN > CCONJ)
        try:
            if l[3]=='CCONJ' and ls3[3]=='NOUN' and l[1].endswith('='):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls3[0]+'\t'+'cc'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel cc (lp=NOUN > CCONJ)
        try:
            if l[3]=='CCONJ' and lp3[3]=='NOUN' and l[1].startswith('='):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp3[0]+'\t'+'cc'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel cc (ls=VERB > CCONJ)
        try:
            if l[3]=='CCONJ' and ls3[3]=='VERB' and l[1].endswith('='):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls3[0]+'\t'+'cc'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel cc (lp=VERB > CCONJ)
        try:
            if l[3]=='CCONJ' and lp3[3]=='VERB' and l[1].startswith('='):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp3[0]+'\t'+'cc'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel comp:obj(lp(VERB)>PRON)
        try:    
            if l[3]=='PRON' and ('OBJ' in l[9]) and lp3[3]=='VERB' and l[1].startswith('='):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp3[0]+'\t'+'comp:obj'+'\t'+l[8]+'\t'+l[9])\
                .split('\t') 
        except IndexError:
            pass
        
        ############################################################################################################
        #contexte 2
        ############################################################################################################
            
        #rel mod:pos(lp(NOUN)>PRON)
        try:
            if l[3]=='PRON' and ('POSS' in l[9]) and lp2[3]=='NOUN' and l[1].startswith('='):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp2[0]+'\t'+'mod:poss'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel det (lp=VERB > DET) avec un autre token entre le VERB et le DET
        try:
            if l[3]=='DET' and lp2[3]=='VERB' and l[1].startswith('='):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp2[0]+'\t'+'det'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel det (ls=VERB > DET)
        try:
            if l[3]=='DET' and ls2[3]=='VERB' and l[1].endswith('='):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls2[0]+'\t'+'det'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel det (ls=NOUN > DET) avec un autre token entre le NOUN et le DET
        try:
            if l[3]=='DET' and ls2[3]=='NOUN' and ls[3]=='DET':
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls2[0]+'\t'+'det'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel det (ls=NOUN > DET)
        try:
            if l[3]=='DET' and ls2[3]=='NOUN' and l[1].endswith('='):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls2[0]+'\t'+'det'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        """  
        #rel det (lp2=NOUN > DET) avec un autre token entre le NOUN et le DET
        try:
            if l[3]=='DET' and lp2[3]=='NOUN' and lp[3]=='DET':
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp2[0]+'\t'+'det'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        """  
        
        #rel det (lp=NOUN > DET) avec un autre token entre le NOUN et le DET
        try:
            if l[3]=='DET' and lp2[3]=='NOUN' and l[1].startswith('='):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp2[0]+'\t'+'det'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel cc (ls=NOUN > CCONJ)
        try:
            if l[3]=='CCONJ' and ls2[3]=='NOUN' and l[1].endswith('='):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls2[0]+'\t'+'cc'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel cc (lp=NOUN > CCONJ)
        try:
            if l[3]=='CCONJ' and lp2[3]=='NOUN' and l[1].startswith('='):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp2[0]+'\t'+'cc'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel cc (ls=VERB > CCONJ)
        try:
            if l[3]=='CCONJ' and ls2[3]=='VERB' and l[1].endswith('='):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls2[0]+'\t'+'cc'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel cc (lp=VERB > CCONJ)
        try:
            if l[3]=='CCONJ' and lp2[3]=='VERB' and l[1].startswith('='):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp2[0]+'\t'+'cc'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel comp (ls=ADP > NOUN)
        try:
            if l[3]=='NOUN' and ls2[3]=='ADP' and ls2[1].startswith('=')==True:
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls2[0]+'\t'+'comp'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel comp (lp=SCONJ > VERB)
        try:
            if l[3]=='VERB' and lp2[3]=='SCONJ' and lp2[1].endswith('=') and ('=REL' in lp2[9]):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp2[0]+'\t'+'comp'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel comp (ls=SCONJ > VERB) relative
        try:
            if l[3]=='VERB' and ls2[3]=='SCONJ' and ls2[1].startswith('=') and ('=REL' in ls2[9]):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls2[0]+'\t'+'comp'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel comp (ls=SCONJ > VERB) when 
        try:
            if l[3]=='VERB' and ls2[3]=='SCONJ' and ls2[1].startswith('=') and ('when' in ls2[9]):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls2[0]+'\t'+'comp'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel comp (lp=SCONJ > AUX)
        try:
            if l[3]=='AUX' and lp2[3]=='SCONJ' and lp2[1].endswith('=') and ('=REL' in lp2[9]):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp2[0]+'\t'+'comp'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel comp (ls=SCONJ > AUX) relative
        try:
            if l[3]=='AUX' and ls2[3]=='SCONJ' and ls2[1].startswith('=') and ('=REL' in ls2[9]):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls2[0]+'\t'+'comp'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel comp:obj(lp(VERB)>PRON)
        if l[3]=='PRON' and ('OBJ' in l[9]) and lp2[3]=='VERB' and l[1].startswith('='):
            l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp2[0]+'\t'+'comp:obj'+'\t'+l[8]+'\t'+l[9])\
            .split('\t')
            
        #rel aff:aux (lp=VERB > AUX)
        try:
            if l[3]=='AUX' and lp2[3]=='VERB' and l[1].startswith('-'):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp2[0]+'\t'+'aff:aux'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel aff:aux (ls=VERB > AUX)
        try:
            if l[3]=='AUX' and ls2[3]=='VERB' and l[1].endswith('-'):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls2[0]+'\t'+'aff:aux'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel aff:subj(ls(VERB)>PRON)
        try:
            if l[1].endswith('-') and l[3]=='PRON' and ('PNG' in l[9]) and ls2[3]=='VERB':
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls2[0]+'\t'+'aff:subj'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel aff:subj(lp(VERB)>PRON)        
        try:
            if l[1].startswith('-') and l[3]=='PRON' and ('PNG' in l[9]) and lp2[3]=='VERB':
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp2[0]+'\t'+'aff:subj'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
                print('££££')
        except IndexError:
            pass
        
        #rel aff:subj(ls(AUX)>PRON)
        try:
            if l[1].endswith('-') and l[3]=='PRON' and ('PNG' in l[9]) and ls2[3]=='AUX':
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls2[0]+'\t'+'aff:subj'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel aff:subj(lp(AUX)>PRON)        
        try:
            if l[1].startswith('-') and l[3]=='PRON' and ('PNG' in l[9]) and lp2[3]=='AUX':
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp2[0]+'\t'+'aff:subj'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
                print('££££')
        except IndexError:
            pass
        
        #rel aff:mark (lp=VERB > CVB aff)
        try:
            if l[3]=='SCONJ' and l[9]=='CVB' and lp2[3]=='VERB' and l[1].startswith('-'):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp2[0]+'\t'+'aff:mark'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel aff:mark (lp=VERB > NV)
        try:
            if l[3]=='SCONJ' and l[9]=='N,V' and lp2[3]=='VERB' and l[1].startswith('-'):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp2[0]+'\t'+'aff:mark'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel aff:mark (lp=VERB > PL)
        try:
            if l[3]=='PART' and l[9]=='PL' and lp2[3]=='VERB' and l[1].startswith('-'):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp2[0]+'\t'+'aff:mark'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel aff:mark (lp=NOUN > PART)
        try:
            if l[3]=='PART' and lp2[3]=='NOUN' and l[1].startswith('-'):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp2[0]+'\t'+'aff:mark'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel aff:aux (lp=VERB > PART)
        if l[3]=='PART' and ('EMPH' in l[9]) and lp2[3]=='VERB' and l[1].startswith('-'):
            l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp2[0]+'\t'+'aff:aux'+'\t'+l[8]+'\t'+l[9])\
            .split('\t')
        
        #rel aff:dep (lp=NOUN > PART)
        try:
            if l[3]=='X' and lp2[3]=='VERB' and l[1].startswith('-'):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp2[0]+'\t'+'aff:dep'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel aff:dep (lp=NOUN > PART)
        try:
            if l[3]=='X' and lp2[3]=='AUX' and l[1].startswith('-'):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp2[0]+'\t'+'aff:dep'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        ############################################################################################################
        #contexte 1
        ############################################################################################################
        
        
        #rel subj(ls(VERB)>PRON)
        if l[3]=='PRON' and ('PRO' in l[9]) and ls[3]=='VERB' and (l[1].startswith('=')==False) and ('ABL' not in l[9]):
            l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls[0]+'\t'+'subj'+'\t'+l[8]+'\t'+l[9])\
            .split('\t')
            
        #rel subj(ls(AUX)>PRON)
        if l[3]=='PRON' and ('PRO' in l[9]) and ls[3]=='AUX':
            l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls[0]+'\t'+'subj'+'\t'+l[8]+'\t'+l[9])\
            .split('\t')
            
        #rel mod:pos(lp(NOUN)>PRON)
        try:
            if l[3]=='PRON' and ('POSS' in l[9]) and lp[3]=='NOUN' and l[1].startswith('='):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp[0]+'\t'+'mod:poss'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel det (lp=VERB > DET)
        try:
            if l[3]=='DET' and lp[3]=='VERB' and l[1].startswith('='):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp[0]+'\t'+'det'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel det (ls=VERB > DET)
        try:    
            if l[3]=='DET' and ls[3]=='VERB' and l[1].endswith('='):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls[0]+'\t'+'det'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel det (ls=NOUN > DET)
        try:
            if l[3]=='DET' and ls[3]=='NOUN' and l[1].endswith('='):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls[0]+'\t'+'det'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel det (lp=NOUN > DET)
        try:
            if l[3]=='DET' and lp[3]=='NOUN' and l[1].startswith('='):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp[0]+'\t'+'det'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
                
        #rel det (ls=ADJ > DET)
        try:
            if l[3]=='DET' and ls[3]=='ADJ' and l[1].endswith('='):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls[0]+'\t'+'det'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
            
        #rel det (ls=ADJ > DET)
        try:
            if l[3]=='DET' and lp[3]=='ADJ' and l[1].startswith('='):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp[0]+'\t'+'det'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
            
        #rel det (ls=SCONJ > DET)
        if l[3]=='DET' and ls[3]=='SCONJ' and l[1].endswith('='):
            l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls[0]+'\t'+'det'+'\t'+l[8]+'\t'+l[9])\
            .split('\t')
        
        #rel det (ls=NOUN > DET)
        try:
            if l[3]=='NUM' and ls[3]=='NOUN':
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls[0]+'\t'+'det:num'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel cc (ls=NOUN > CCONJ)
        try:
            if l[3]=='CCONJ' and ls[3]=='NOUN' and l[1].endswith('='):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls[0]+'\t'+'cc'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel cc (lp=NOUN > CCONJ)
        try:
            if l[3]=='CCONJ' and lp[3]=='NOUN' and l[1].startswith('='):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp[0]+'\t'+'cc'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel cc (ls=VERB > CCONJ)
        try:
            if l[3]=='CCONJ' and ls[3]=='VERB' and l[1].endswith('='):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls[0]+'\t'+'cc'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel cc (lp=VERB > CCONJ)
        try:
            if l[3]=='CCONJ' and lp[3]=='VERB' and l[1].startswith('='):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp[0]+'\t'+'cc'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel comp (lp=ADP > NOUN)
        try:
            if l[3]=='NOUN' and lp[3]=='ADP' and lp[1].endswith('='):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp[0]+'\t'+'comp'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel comp (ls=ADP > NOUN)
        try:
            if l[3]=='NOUN' and ls[3]=='ADP' and ls[1].startswith('=')==True:
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls[0]+'\t'+'comp'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel mod:poss (lp=ADP > PRON)
        try:
            if l[3]=='PRON' and lp[3]=='ADP' and l[1].startswith('=') and ('POSS' in l[9]):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp[0]+'\t'+'mod:poss'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel mod:poss (ls=ADP > PRON)
        try:
            if l[3]=='PRON' and ls[3]=='ADP' and ls[1].endswith('=')==True and ('POSS' in l[9]):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls[0]+'\t'+'mod:poss'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel comp (lp=ADP > PRON)
        try:
            if l[3]=='PRON' and lp[3]=='ADP' and l[1].endswith('='):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp[0]+'\t'+'comp'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel comp (lp=SCONJ > VERB)
        try:
            if l[3]=='VERB' and lp[3]=='SCONJ' and lp[1].endswith('=') and ('=REL' in lp[9]):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp[0]+'\t'+'comp'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel comp (ls=SCONJ > VERB) relative
        try:
            if l[3]=='VERB' and ls[3]=='SCONJ' and ls[1].startswith('=') and ('=REL' in ls[9]):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls[0]+'\t'+'comp'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel comp (ls=SCONJ > VERB) when 
        try:
            if l[3]=='VERB' and ls[3]=='SCONJ' and ls[1].startswith('=') and ('when' in ls[9]):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls[0]+'\t'+'comp'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel comp (lp=SCONJ > AUX)
        try:
            if l[3]=='AUX' and lp[3]=='SCONJ' and lp[1].endswith('=') and ('=REL' in lp[9]):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp[0]+'\t'+'comp'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel comp (ls=SCONJ > AUX) relative
        try:
            if l[3]=='AUX' and ls[3]=='SCONJ' and ls[1].startswith('=') and ('=REL' in ls[9]):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls[0]+'\t'+'comp'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
            
        #rel comp:obj(lp(VERB)>PRON)
        if l[3]=='PRON' and ('OBJ' in l[9]) and lp[3]=='VERB' and l[1].startswith('='):
            l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp[0]+'\t'+'comp:obj'+'\t'+l[8]+'\t'+l[9])\
            .split('\t') 
            
        #rel comp:obj(ls(VERB)>PRON)
        if l[3]=='PRON' and ('OBJ' in l[9]) and ls[3]=='VERB' and l[1].endswith('='):
            l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls[0]+'\t'+'comp:obj'+'\t'+l[8]+'\t'+l[9])\
            .split('\t')
            
        #rel comp:obl(ls(VERB)>PRON)
        if l[3]=='PRON' and ('ABL' in l[9]) and ls[3]=='VERB' and l[1].endswith('=')==False and l[1].endswith('-')==False:
            l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls[0]+'\t'+'comp:obl'+'\t'+l[8]+'\t'+l[9])\
            .split('\t')
            
        #rel comp:obl(ls(VERB)>PRON)
        if l[3]=='PRON' and ('DAT' in l[9]) and ls[3]=='VERB' and l[1].endswith('=')==False and l[1].endswith('-')==False:
            l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls[0]+'\t'+'comp:obl'+'\t'+l[8]+'\t'+l[9])\
            .split('\t')
            
        #rel aff:aux (lp=VERB > AUX)
        try:
            if l[3]=='AUX' and lp[3]=='VERB' and l[1].startswith('-'):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp[0]+'\t'+'aff:aux'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel aff:aux (ls=VERB > AUX)
        try:
            if l[3]=='AUX' and ls[3]=='VERB' and l[1].endswith('-'):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls[0]+'\t'+'aff:aux'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel aff:subj(ls(VERB)>PRON)
        if l[1].endswith('-') and l[3]=='PRON' and ('PNG' in l[9]) and ls[3]=='VERB':
            l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls[0]+'\t'+'aff:subj'+'\t'+l[8]+'\t'+l[9])\
            .split('\t')
        
        #rel aff:subj(lp(VERB)>PRON)
        try:
            if l[1].startswith('-') and l[3]=='PRON' and ('PNG' in l[9]) and lp[3]=='VERB':
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp[0]+'\t'+'aff:subj'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel aff:subj (lp=AUX > PRON) (préposé)   
        try:    
            if l[3]=='PART' and ('PNG' in l[9]) and lp[3]=='AUX' and l[1].startswith('-') and ls[1].startswith('-')==False:
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+'PRON'+'\t'+l[4]+'\t'+l[5]+'\t'+lp[0]+'\t'+'aff:subj'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel aff:subj (ls=AUX > PRON) (postposé)   
        try:    
            if l[1].endswith('-') and l[3]=='PART' and ('PNG' in l[9]) and ls[3]=='AUX' and ls[1].endswith('-')==False:
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+'PRON'+'\t'+l[4]+'\t'+l[5]+'\t'+ls[0]+'\t'+'aff:subj'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel aff:subj (lp=AUX > PRON) (préposé)   
        try:    
            if l[1].startswith('-') and l[3]=='PRON' and ('PNG' in l[9]) and lp[3]=='AUX' and lp[1].startswith('-')==False:
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp[0]+'\t'+'aff:subj'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel aff:subj (ls=AUX > PRON) (postposé)   
        try:    
            if l[1].endswith('-') and l[3]=='PRON' and ('PNG' in l[9]) and lp[3]=='AUX' and ls[1].endswith('-')==False:
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+ls[0]+'\t'+'aff:subj'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
            
        #rel aff:aux (lp=VERB > PART)
        if l[3]=='PART' and ('EMPH' in l[9]) and lp[3]=='VERB' and l[1].startswith('-'):
            l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp[0]+'\t'+'aff:aux'+'\t'+l[8]+'\t'+l[9])\
            .split('\t')    
            
        #rel aff:case (lp=NOUN > PART)
        if l[3]=='PART' and ('CASE' in l[9]) and lp[3]=='NOUN' and l[1].startswith('-'):
            l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp[0]+'\t'+'aff:case'+'\t'+l[8]+'\t'+l[9])\
            .split('\t')
        
        #rel aff:mark (lp=VERB > CVB aff)
        try:
            if l[3]=='SCONJ' and ('CVB' in l[9]) and lp[3]=='VERB' and l[1].startswith('-'):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp[0]+'\t'+'aff:mark'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel aff:mark (lp=VERB > NV)
        try:
            if l[3]=='SCONJ' and ('N,V' in l[9]) and lp[3]=='VERB' and l[1].startswith('-'):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp[0]+'\t'+'aff:mark'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel aff:mark (lp=VERB > PL)
        try:
            if l[3]=='PART' and ('PL' in l[9]) and lp[3]=='VERB' and l[1].startswith('-'):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp[0]+'\t'+'aff:mark'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel aff:mark (lp=NOUN > PART)
        try:
            if l[3]=='PART' and lp[3]=='NOUN' and l[1].startswith('-'):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp[0]+'\t'+'aff:mark'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel aff:dep (lp=NOUN > PART)
        try:
            if l[3]=='X' and lp[3]=='VERB' and l[1].startswith('-'):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp[0]+'\t'+'aff:dep'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass
        
        #rel aff:dep (lp=NOUN > PART)
        try:
            if l[3]=='X' and lp[3]=='AUX' and l[1].startswith('-'):
                l = (l[0]+'\t'+l[1]+'\t'+l[2]+'\t'+l[3]+'\t'+l[4]+'\t'+l[5]+'\t'+lp[0]+'\t'+'aff:dep'+'\t'+l[8]+'\t'+l[9])\
                .split('\t')
        except IndexError:
            pass

        print(l)
        out.write("\t".join(l))
# Out:
# # text = tak / kaːmi / hoː kʷiɖja ini //
#
# # tokenized_text = tak / kaːm =i / hoː kʷiɖ -ja i- ni //
#
# # text_en = A man said: "My camel disappeared.
#
# ['1', 'tak', '_', 'NOUN', 'N', 'Gender=Masc', '_', '_', '_', 'RX= SBJ,N,M|Gloss= man|Times= 0, 190\n']
# ['2', '/', '_', 'PUNCT', 'PUNCT', '_', '_', '_', '_', 'GE= PUNCT|RX= PUNCT|Times= 190, 879\n']
# ['3', 'kaːm', '_', 'NOUN', 'N', '_', '_', '_', '_', 'RX= SBJ,N|Gloss= camel|Times= 879, 982\n']
# ['4', '=i', '_', 'PRON', 'PRO', 'Poss=Yes|Person=1|Number=Sing|Case=Nom', '3', 'mod:poss', '_', 'GE= =POSS,1SG,NOM|RX= =PRO|Times= 982, 1085\n']
# ['5', '/', '_', 'PUNCT', 'PUNCT', '_', '_', '_', '_', 'GE= PUNCT|RX= PUNCT|Times= 1085, 1815\n']
# ['6', 'hoː', '_', 'PRON', 'PRO', 'Person=1|Number=Sing|Case=Dat', '7', 'comp:obl', '_', 'GE= 1SG,DAT|RX= PRO|Times= 1815, 2092\n']
# ['7', 'kʷiɖ', '_', 'VERB', 'V2', 'VerbClass=2', '_', '_', '_', 'RX= V2|Gloss= disappear|Times= 2092, 2231\n']
# ...
